# %%
print("hello world")

# %% [markdown]
# <div id="colab-badge-container">
#   <a href="https://colab.research.google.com/github/gsclaros/test-notebook/blob/main/docs/notebooks/hello_world.ipynb" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#   </a>
# </div>
#
# <script>
#   if (window.location.hostname === 'colab.research.google.com') {
#     var badge = document.getElementById('colab-badge-container');
#     if (badge) {
#       badge.style.display = 'none';
#     }
#   }
# </script>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gsclaros/test-notebook/blob/main/docs/notebooks/hello_world.ipynb)

# %%
import pyomo.environ as pyo
