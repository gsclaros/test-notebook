# %% [markdown]
# This is an example hereeee

# %%
print("howdy")

# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/gsclaros/test-notebook.git/HEAD?urlpath=%2Fdoc%2Ftree%2Ftest.ipynb)
